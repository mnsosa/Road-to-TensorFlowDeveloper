# %% [markdown]
# <a href="https://colab.research.google.com/github/mnsosa/TensorFlowDeveloperCertificate/blob/main/Course-1%3A%20Introduction%20to%20TF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to TensorFlow for Artificial Intelligence, Machine Learning, and Deep Learning

# %% [markdown]
# # Semana 1

# %% [markdown]
# ## A new programming paradigm

# %% [markdown]
# Son para problemas en donde es dificil poder definir las reglas uno mismo. El algoritmo encuentra los patrones por sí mismo, las reglas que definen el sistema.
#
# El curso se trata de Deep Learning.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## The ‘Hello World’ of neural networks
